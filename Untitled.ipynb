# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
sns.set_style("whitegrid")
pal = sns.color_palette()


men_means = (1.29, 1.14, 0.98)
women_means = (1.22, 1.11, 0.96)

ind = np.arange(len(men_means))  # the x locations for the groups
width = 0.35  # the width of the bars

with sns.color_palette("deep", 5):
    fig, ax = plt.subplots()
    rects1 = ax.bar(ind - width/2, men_means, width, label='unet-b')
    rects2 = ax.bar(ind + width/2, women_means, width, label='unet-pc')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Error (mse)')
    plt.rcParams.update({'font.family':'Helvetica'})

    ax.set_xticks(ind)
    ax.set_xticklabels(('10k samples', '100k samples', '1m samples'))
    ax.legend(prop={'family':"Helvetica", 'size':10})


# def autolabel(rects, xpos='center'):
#     """
#     Attach a text label above each bar in *rects*, displaying its height.

#     *xpos* indicates which side to place the text w.r.t. the center of
#     the bar. It can be one of the following {'center', 'right', 'left'}.
#     """

#     ha = {'center': 'center', 'right': 'left', 'left': 'right'}
#     offset = {'center': 0, 'right': 1, 'left': -1}

#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(offset[xpos]*3, 3),  # use 3 points offset
#                     textcoords="offset points",  # in both directions
#                     ha=ha[xpos], va='bottom')


# autolabel(rects1, "left")
# autolabel(rects2, "right")

fig.tight_layout()
plt.savefig("visuals/sampleff.eps", filetype="eps")

# %%
import seaborn as sns
sns.set(style="whitegrid")

# Load the example Titanic dataset
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x=[1, 2, 3, 1, 2, 3], y=[2, 3, 4, 5, 6, 7], hue=["baseline", "percep", "baseline", "percep", "baseline", "percep"], data=titanic,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("survival probability")
